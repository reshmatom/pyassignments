# %%
1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %%
Recurrence Relation
𝑇(𝑛)=3𝑇(𝑛−1)+12𝑛

Given 
T(0)=5.

n=1,   
𝑇(1)= 3𝑇(0) + 12⋅1
𝑇(1)=3 ⋅5 + 12
T(1)= 15 + 12 
T(1)= 27

n=2,
T(2)= 3T(1) + 12⋅2
T(2)= 3⋅27 + 24 
T(2)= 81 + 24 
𝑇(2)= 105

The value of T(2) is 105

# %%
2. Given a recurrence relation, solve it using the substitution method:
a. T(n) = T(n-1) + c
b. T(n) = 2T(n/2) + n
c. T(n) = 2T(n/2) + c
d. T(n) = T(n/2) + c

# %%
To solve recurrence relations using the substitution method, we make an educated guess (or hypothesis) about the form of the 
solution and then use mathematical induction to prove it. Here’s how you can approach each of the given recurrence relations:

### a.  T(n) = T(n-1) + c 

**Hypothesis:** Let  T(n) = an + b .

Substitute into the recurrence relation:

 Assume  T(n) = an + b 
 Substitute into the recurrence relation:
   T(n) = T(n-1) + c
   T(n) = a(n-1) + b + c
   T(n) = an - a + b + c
   an - a + b + c = an + b
   
 Solving for a  and  b:
   -a + c = 0 implies a = c

   b is the constant term and remains b.

Solution:
    T(n) = cn + b
   
   Given the initial condition 
                 T(0)=T 0, we find 𝑏=𝑇0

General Solution:
   T(n) = cn + T0



### b.  T(n) = 2T(n/2) + n 

Hypothesis: Let T(n)= anlogn + b. 

Substitute into the recurrence relation:

Assume T(n)= anlogn+b
T(n) = 2[ a(n/2 log n/2)+b]+ n
T(n) = an log n/2 + 2b + n
T(n) = an(logn−log2)+2b+n
T(n) = anlogn−anlog2+2b+n

To match the original form T(n)=anlogn+b, we need
      −alog2+1 = 0
⟹    a = 1 /log2
      b = 2b− an log2
To simplify, we use a=1, b=constant.

Solution:
​
   T(n) = nlogn + O(n)



c. T(n)=2T(n/2)+c
Hypothesis: Let T(n)=anlogn+b.

Substitute into the recurrence relation:

Assume T(n)=anlogn+b.
Substitute into the recurrence relation:

T(n)=2T(n/2)+c

T(n)=2[a( 2nlog 2n)+b]+c

T(n)=an log 2n+2b+c

T(n)=an(logn−log2)+2b+c

T(n)=anlogn−anlog2+2b+c

To match the original form T(n)=anlogn+b, 
   we get:   a=a

  b=2b−anlog2+c

To match:
a=2, b=c

Solution:

  T(n) = Θ(nlogn)




### d.  T(n) = T(n/2) + c 

 Assume  T(n) = a log n + b 
 Substitute into the recurrence relation:
   
   T(n) = a log n/2 +b +c
   T(n) = a(log n- log2) +b +c
   T(n) = alogn - alog2 +b+c

To match the original form   T(n)=alogn+b:
                                a = a
                                b = −alog2+b+c
                                −alog2 + c = 0


Solving gives a=constant.

Solution:

 T(n) = Θ(logn)

# %%
3. Given a recurrence relation, solve it using the recursive tree approach:
a. T(n) = 2T(n-1) +1
b. T(n) = 2T(n/2) + n

# %%
Recursive Tree Approach:

a.   Draw the Recursive Tree:

At the root (level 0), we have T(n).
At level 1, this splits into two subproblems: 

T(n−1) and T(n−1), with an additional cost of 1.
At level 2, each T(n−1) further splits into 
2×T(n−2) with an additional cost of 1, and so on.

 Cost at Each Level:

Level 0: Cost = 1
Level 1: Cost = 2
Level 2: Cost = 4
...
Level k: Cost = 2^k

The total cost at each level doubles as we go down the tree. The depth of the tree is n since the smallest problem we can get to is 
T(1), which implies the tree has n levels.

Total Cost Calculation:

Sum the costs across all levels:

Total Cost = 1+2+4+⋯+2^n−1
This is a geometric series with the sum:
Total Cost = 2^n -1 
T(n) grows as 2^n, so the time complexity is O(2^n)
​

b. T(n)=2T(n/2)+n  

Draw the Recursive Tree:

At the root (level 0), we have T(n).
At level 1, this splits into two subproblems:  T(n/2) and T(n/2), with an additional cost of 𝑛
At level 2, each T(n/2) further splits into T(n/4), and so on.

Cost at Each Level:

Level 0: Cost = 𝑛
Level 1: Cost = 2× 𝑛/2 = 𝑛
Level 2: Cost = 4× 𝑛/4 = 𝑛
Level k: Cost = 𝑛

The cost at each level remains 𝑛 and the tree has log 𝑛 levels because the problem size halves at each level until it reaches 1.

Total Cost Calculation:

Sum the costs across all levels:

Total Cost=n+n+n+⋯+n(logn times)
Total Cost=n×logn
